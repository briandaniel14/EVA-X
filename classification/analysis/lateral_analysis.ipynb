# %%
import pandas as pd

train_full_path = "../../data/train.csv"
valid_full_path = "../../data/valid.csv"


df_train_full = pd.read_csv(train_full_path)
df_valid_full = pd.read_csv(valid_full_path) 

df_valid_full_lateral = df_valid_full[df_valid_full['Frontal/Lateral']=="Lateral"]
len(df_valid_full_lateral)
# Out:
# 32
